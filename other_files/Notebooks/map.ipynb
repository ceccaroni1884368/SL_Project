# %%
import geopandas
import contextily as ctx
# %matplotlib inline

df = geopandas.read_file(geopandas.datasets.get_path('nybb'))
ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')

df = df.to_crs(epsg=3857)


ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')
ctx.add_basemap(ax)

ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')
ctx.add_basemap(ax, zoom=12)


ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')
ctx.add_basemap(ax, url=ctx.providers.Stamen.TonerLite)
ax.set_axis_off()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-af18dd92d790> in <module>
#       1 import geopandas
# ----> 2 import contextily as ctx
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4
#       5 df = geopandas.read_file(geopandas.datasets.get_path('nybb'))
#
# ModuleNotFoundError: No module named 'contextily'

# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt

df = pd.read_csv('../../data/20200326-114144.csv')

# %%
gdf = geopandas.GeoDataFrame(
    df, geometry=geopandas.points_from_xy(df.lon, df.lat))

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# %%
#from matplotlib.pyplot import figure
fig = plt.figure(figsize=(2, 5))
fig = world[world.continent == 'North America'].plot(
    color='white', edgecolor='royalblue')
# We can now plot our ``GeoDataFrame``.
gdf.plot(ax=fig, color='red', markersize=3, alpha=0.6)
plt.show()
fig.savefig('temp.png', dpi=fig.dpi)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-88d904230829> in <module>
#       6 gdf.plot(ax=fig, color='red', markersize=3, alpha=0.6)
#       7 plt.show()
# ----> 8 fig.savefig('temp.png', dpi=fig.dpi)
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'
